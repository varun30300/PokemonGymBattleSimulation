# %%
'''
TITLE - POKEMON GYM BATTLE SIMULATION

Started - 11/12/2018 
Finished - 12/12/2018 (12:37am)

author @ BeastMaster
testing @ BOBO
'''
from IPython.display import clear_output
import random

#----------------------------------------------------------------------------#
class basicInfo:
	def __init__(self,name1,name2,hp,cp):
		self.name1=name1
		self.name2=name2
		self.hp=hp
		self.cp=1
	def showData(self):                                                  # 
		print(self.name1)                                            #
		print(self.hp)                                               #
		print(self.cp)                                               #
                                                                             #
#----------------------------------------------------------------------------#
		                                                             #
class pkmn(basicInfo):                                                       #  
	def evolve(self):                                                    #
		self.name1=self.name2                                        # 
		self.hp=self.hp+10                                           #
		self.cp=self.cp+0.1                                          #  
                                                                             #
                                                                             #
                                                                             #
#----------------------------------------------------------------------------#
        
     

class attacklist:
    def __init__(self):
        self.attacks = {"Chimchar":[['Scratch', 10],['Ember', random.randint(10, 30)],['SerialSwipes', random.randint(10, 20)],['Flare', random.randint(10, 20)]],
                        "Squirtle":[['Tackle', random.randint(10, 15)],['Bite',random.randint(10, 20)],['WaterGun',random.randint(10, 30)],['SkullBash',10]],
                        "Hitmonlee":[['MegaKick', random.randint(10, 40)],['SpiralKick',random.randint(10, 30)],['GutKick',random.randint(10, 30)],['HighJumpKick',random.randint(10, 60)]],
                        "Gastly":[['Lick', random.randint(10, 20)],['NightMare',random.randint(10, 20)],['NightShade',random.randint(10, 30)],['Gnaw',random.randint(10, 20)]],
                        "Oshawott":[['tackle',random.randint(10, 15)],['waterGun',random.randint(10, 30)],['razorShell',random.randint(10, 30)],['rainSplash',10]],
                        "Nidoran":[['tackle',random.randint(10, 15)],['bite',random.randint(10, 20)],['hornAttack',random.randint(10, 20)],['hornHazard',random.randint(10, 40)]],
                        "Machope":[['MegaKick',random.randint(10, 40)],['KnucklePunch',random.randint(10, 20)],['KarateChop',random.randint(10, 30)],['MachCross',random.randint(10, 50)]],
                        "Charmander":[['Scratch',10],['Ember',random.randint(10, 30)],['Bite',random.randint(10, 20)],['FlameTail',random.randint(10, 20)]],
                        "Bulbasaur":[['Bite',random.randint(10, 20)],['Tackle',random.randint(10, 15)],['VineWipe',random.randint(10, 30)],['BulletSeed',random.randint(10, 20)]],
                        "Pikachu":[['Scratch',10],['IronTail',random.randint(10, 20)],['OverSpark',random.randint(10, 30)],['ThunderBolt',random.randint(10, 60)]],
                        "Diglett":[['MudSpatter',random.randint(10, 40)],['SandPit',random.randint(10, 20)],['MudSlap',10],['Ram',random.randint(10, 20)]],
                        "Ekains":[['Bite',random.randint(10, 20)],['PoisonSting',random.randint(10, 20)],['TailSnap',random.randint(10, 30)],['PoisonFang',10]]}

        
#----------------------------------------------------------------------------#

class fight(pkmn):   
    def __init__(self):
        tres = 0
        ores = 0
        chimchar = pkmn("Chimchar","Monferno",100,1)
        squirtle = pkmn("Squirtle","Wartortle",100,1)
        hitmonlee = pkmn("Hitmonlee","Hitmoncham",100,1)
        gastly = pkmn("Gastly","Haunter",100,1)
        oshawott = pkmn("Oshawott","Dewott",100,1)
        nidoran = pkmn("Nidoran","Nidorino",100,1)
        machope = pkmn("Machope","Machoke",100,1)
        charmander = pkmn("Charmander","Charmeleon",100,1)
        bulbasaur = pkmn("Bulbasaur","Ivysaur",100,1)
        pikachu = pkmn("Pikachu","Raichu",100,1)
        diglett = pkmn("Diglett","Dugtrio",100,1)
        ekains = pkmn("Ekains","Arbok",100,1)
        index = random.randint(0, 5)
        match = 0
        objT = [chimchar, squirtle, hitmonlee, gastly, oshawott, nidoran]
        objO = [machope, charmander, bulbasaur, pikachu, diglett, ekains]        
        atks = attacklist()
        used_pkmn = []
        while match < 6 :
            
            opokemon = [[machope.name1,machope.hp,machope.cp,machope.name2],[charmander.name1,charmander.hp,charmander.cp,charmander.name2],[bulbasaur.name1,bulbasaur.hp,bulbasaur.cp,bulbasaur.name2],[pikachu.name1,pikachu.hp,pikachu.cp,pikachu.name2],[diglett.name1,diglett.hp,diglett.cp,diglett.name2],[ekains.name1,ekains.hp,ekains.cp,ekains.name2]]
            tpokemon = [[chimchar.name1,chimchar.hp,chimchar.cp,chimchar.name2],[squirtle.name1,squirtle.hp,squirtle.cp,squirtle.name2],[hitmonlee.name1,hitmonlee.hp,hitmonlee.cp,hitmonlee.name2],[gastly.name1,gastly.hp,gastly.cp,gastly.name2],[oshawott.name1,oshawott.hp,oshawott.cp,oshawott.name2],[nidoran.name1,nidoran.hp,nidoran.cp,nidoran.name2]]
            print("MATCH" , match+1)
            #___________Choose pkmn
            for i in range(6):
                print(i+1, "-->", tpokemon[i][0])
            while(True):                
                c = (input("Choose a Pokemon :-"))                
                if(c > '6' or c == '' or c < '1'):
                    print("Invalid Choice. Please Try again.")
                elif (int)(c) in used_pkmn:
                    print("This pokemon has already been in battle. Choose another pokemon.")                        
                else:
                    c = (int)(c)
                    used_pkmn.append(c)
                    break
            print("You choose" , tpokemon[c-1][0] )
            grypkmn = (index+match)%6
            print("Garry choose", opokemon[grypkmn][0])
            input("Press Enter to continue")
            clear_output()
            #__________Exchange attacks            
            while (tpokemon[c-1][1] > 0 and opokemon[grypkmn][1] > 0) :
                print("Attack list of", tpokemon[c-1][0], ":")
                i = 1
                for x, y in atks.attacks[tpokemon[c-1][0]]:
                    print(i, "- ", x)
                    i += 1
                while(True):
                    ch = (input("Choose your attack : "))
                    if ch >= '1' and ch <= '4' :                        
                        break
                    else:
                        print("Invalid Choice. Please Try again.")
                ch = (int)(ch)
                clear_output()
                print("Damage inflicted by", atks.attacks[tpokemon[c-1][0]][ch-1][0], "=", atks.attacks[tpokemon[c-1][0]][ch-1][1])
                gry = random.randint(0, 3)
                print("Gary used", atks.attacks[opokemon[grypkmn][0]][gry][0])
                print("Damage inflicted by", atks.attacks[opokemon[grypkmn][0]][gry][0], "=", atks.attacks[opokemon[grypkmn][0]][gry][1])
                tpokemon[c-1][1] -= (tpokemon[c-1][2] * atks.attacks[opokemon[grypkmn][0]][gry][1])                
                opokemon[grypkmn][1] -= (opokemon[grypkmn][2] * atks.attacks[tpokemon[c-1][0]][ch-1][1])
                if(tpokemon[c-1][1] >= 0 and opokemon[grypkmn][1] >= 0):
                    print("Your pokemon ", tpokemon[c-1][0], "'s health : ", tpokemon[c-1][1], "    Gary's pokemon ", opokemon[grypkmn][0], "'s health : ", opokemon[grypkmn][1], sep = '')            
            clear_output()
            if tpokemon[c-1][1] > opokemon[grypkmn][1] :
                print("Gary's Pokemon's HP = 0\nYou won this round!", 5-match, "rounds to go")
                tres += 1
            elif tpokemon[c-1][1] < opokemon[grypkmn][1]:
                print("Your Pokemon's HP = 0\nGary won this round.", 5-match, "rounds to go")
                ores += 1
            else:
                print("Its a tie.", 5-match, "rounds to go")
            print("Your pokemon", tpokemon[c-1][0], "evolved to", tpokemon[c-1][3])
            objT[c-1].evolve()
            match += 1
            q = input("Press enter to continue")
            clear_output()
            #___________    
        print("MATCH OVER")
        print(trainer, "points\t", "Gary points")
        print(tres, "\t\t",ores)
#----------------------------------------------------------------------------#

trainer = input(("Trainer, state your name :- "))
print ("Trainer " , trainer , ", Gym Leader Garry awaits you", sep = '')
print("There are going to be 6 matches")
print ("PRESS 1 TO START BATTLE")
resp = (input("Your Response :- "))
clear_output()
if resp == '1' :
    print ("YOUR POKEMONS")    
else :
    print("I asked u to PRESS 1 , but anyways THESE ARE YOUR POKEMONS")    
bat = fight()

#----------------------------------------------------------------------------#
# Out:
# Damage inflicted by Scratch = 10
# Gary used SandPit
# Damage inflicted by SandPit = 20
# Your pokemon Chimchar's health : 80    Gary's pokemon Diglett's health : 90
# Attack list of Chimchar :
# 1 -  Scratch
# 2 -  Ember
# 3 -  SerialSwipes
# 4 -  Flare
